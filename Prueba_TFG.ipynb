# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverosmamoya2004-del/Nueva-prueba/blob/main/Prueba_TFG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Probando
print('Hola mundo')
# Out:
# Hola mundo

# %%
# !git clone https://github.com/oliverosmamoya2004-del/Nueva-prueba.git
# Out:
# Cloning into 'Nueva-prueba'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# Out:
# Nueva-prueba  sample_data
